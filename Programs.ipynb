# %% [markdown]
# ######  Anagram

# %%
#Anagram Method 1
def anagram(s1,s2):
    if(len(s1) != len(s2)):
        return(False)
    else:
        d = {}
        for i in s1:
            if i not in d:
                d[i] = 1
            else:
                d[i] += d[i]+1

        for i in s2:
            if i not in d:
                return(False)
            if i in d:
                d[i] = d[i]-1
        for i in d:
            if d[i] !=0:
                return(False)

        return True

# Another

s1 = input()
s2 = input()
s1 = s1.replace(" ","")
s2 = s2.replace(" ","")
if (len(s1) != len(s2)) or (sorted(s1) != sorted(s2)):
    print(False)
else:
    print(True)

s1 = input()
s2 = input()
s1 = s1.replace(" ","")
s2 = s2.replace(" ","")
print(anagram(s1,s2))


# Another
s1 = input()
s2 = input()
s1 = s1.replace(" ","")
s2 = s2.replace(" ","")
if(len(s1) != len(s2)):
    print(False)
else:
    for i in s1:
        if s1.count(i) != s2.count(i):
            print(False)
            break
    print(True)

# %% [markdown]
# ######  Rounded Integer

# %%
# An integer is round if it is greater than 0 and the sum of its digits in decimal representation is a multiple of 10.
# Find an optimal procedure to compute the N−th smallest round integer. 
# E.g. If N=2 then Answer is 28As the first round integer is 19(1+9=10) and the second round integer is 28(2+8=10)

t = input()
for _ in range(int(t)):
    n = int(input())
    val = 19
    l=[]
    c = 0
    while val>=19:
        s = str(val)
        k = 0
        for i in s:
            k = k+int(i)
        if k%10==0:
            c=c+1
            l.append(val)
        if c==n:
            break
        val += 1
    print(l[n-1])

# %% [markdown]
# ###### largest continuous sum

# %%
def calculate_sum(arr):
    s = 0
    m = 0
    for i in arr:
        s = s+i
        if m<s:
            m=s
    return m
print(calculate_sum([1,2,-1,3,4,10,10,-10,-1]))

# %% [markdown]
# ###### Missing Element

# %%
# Missing element in the list

def find_element(arr1,arr2):
    l=[]
    for i in arr1:
        if i not in arr2:
            l.append(i)
    print(l)

find_element([1,2,3,4,5,6,7,8],[4,3,1,2,5,7,6])

# Method 2

def finder(arr1,arr2):
    d = {}
    l = []
    for i in arr2:
        if i not in d:
            d[i] = 1
        else:
            d[i] += 1
    for i in arr1:
        if i not in d:
            l.append(i)
    return l
print(finder([1,2,3,4],[1,2,3,6]))

# Another

import collections


def finder(arr1,arr2):
    d = collections.defaultdict(int)
    l = []
    for i in arr2:
        d[i] +=1
    for i in arr1:
        if d[i] ==0:
          l.append(i)
    print(l)
finder([1,2,2,4],[1,3,4])

# The last one
def finder3(arr1,arr2):
    result = 0
    print(arr1+arr2)
    for i in arr1+arr2:
        result ^= i
        #print(result)
    return result

print(finder3([1,2,3,4,5],[1,2,4,5]))

# %% [markdown]
# ###### Dynamic Array

# %%
#This is an implementation of Dynamic Array
import ctypes
import sys

class Dynamic():
    """ Dynamic Array Class """
    
    def __init__(self):
        """ Initializing new array """
        self.n = 0
        self.capacity = 1
        self.A = self._make_array(self.capacity)
    
    def __len__(self):
        """ Returns length of the array """
        return self.n
    
    def __getitem__(self,k):
        """ Returns the item at index k """
        if not 0<= k < self.n:
            return IndexError("Index outof bounds")
        return self.A[k]

    def append(self,v):
        """ Appends value to given array """
        if self.n == self.capacity:
            self.capacity = 2*self.capacity
            B = self._make_array(self.capacity)
            for i in range(self.n):
                B[i] = self.A[i]
            self.A = B
        self.A[self.n] = v
        self.n = self.n+1
    def _make_array(self,newcap):
        return (newcap*ctypes.py_object)()

arr = Dynamic()

###################################################################################
import ctypes

class Dynamic():
    """ This is the implemention of dynamic array """
    def __init__(self):
        """ Initializing to new array """
        self.n = 0
        self.capacity = 1
        self.A = self.make_array(self.capacity)
    
    def __getitem__(self, k):
        """ Returns the item in the index of the array """
        if not( 0<= k < self.n):
            return IndexError("Index out of bounds..!")
        return self.A[k]
    def __len__(self):
        """ Returns the length of the array """
        return self.n

    def append(self, value):
        """ Appends the value to the array """
        if self.n == self.capacity:
            B = self.make_array(2*self.capacity)
            for i in range(self.n):
                B[i] = self.A[i]
            self.A = B
        self.A[self.n] = value
        self.n = self.n+1
        
        
    def make_array(self,capacity):
        """ Creates new array object using ctypes """
        return (capacity * ctypes.py_object)()

# %% [markdown]
# ######  Pairs Sum

# %%
# Array pair sum

# Method 1

def pair(arr,s):
    k = set()
    for i in arr:
        if s-i in arr:
            #k.add((i,s-i))
            k.add((min(i,s-i),max(i,s-i)))
    
    print(k)


pair([1,2,3,4,5,6,7,8],10)

#  Method 2
# have to check this 
def pairs_sum(arr,s):
    
    seen = set()
    out = set()
    for i in arr:
        target = s - i
        if target not in seen:
            seen.add(target)
        else:
            out.add(min(i,target),max(i,target))
    print(seen)
    print(out)
    
pairs_sum([1,2,3,4,5,6,7,8],10)

# %% [markdown]
# ###### Stacks & Queues

# %%
# Program for stack implementation

class Stack():
    """ Stack class """
    def __init__(self):
        """ Initializes stack class """
        self.n = 0
        self.A = []
        
    def push(self, value):
        """ Pushes element into the stack """
        self.A.append(value)
        self.n += 1
    
    def pop(self):
        """ Removes top element from stack and returns it """
        if self.n < 1:
            return "No elements are present in the stack"
        else:
            top_value = self.A[self.n-1]
            del self.A[self.n-1]
            self.n -= 1
            return top_value
    
    def peak(self):
            """ Returns top element """
            if self.n < 1:
                return "No elements are present in the stack"
            else:
                return self.A[self.n-1]
    def isEmpty(self):
        if self.n < 1:
            return True
        return False
    def size(self):
        return self.n

# Abstract Data Type Queue Implementation

class Queue():
    """ Abstract Data Type Queue Class"""
    def __init__(self):
        """ Initializes Queue """
        self.items = []
        
    def isEmpty(self):
        """ Returns True if queue is empty, else False """
        return self.items == []
    
    def enqueue(self, item):
        """ Insert value at the beginning """
        self.items.insert(0,item)
    
    def dequeue(self):
        """ Removes first inserted element """
        if len(self.items) != 0:
            return self.items.pop()
        else:
            return "No items found in the queue"
    
    def size(self):
        """ Returns the size of queue """
        return len(self.items)

# %% [markdown]
# ###### Unique Characters

# %%
# No corner cases checked

# Unique character string
# Method-I

def unique(string):
    if len(set(string)) != len(string):
        return False
    else: 
        return True
print(unique("abcde"))

# Method-II

def uniquechr(string):
    for i in string:
        if string.count(i) != 1:
            return False
    return True
print(uniquestr("abbcd"))

# Method -III

def uniquechr(string):
    d = {}
    for i in string:
        if i not in d:
            d[i] = 1
        else:
            return False
    return True
print(uniquechr(""))

# %% [markdown]
# ###### HackerEarth Samsung Software Developer

# %%
# Problem one
# A =[1,2,3..n] ntimes
# B = [1,2,3..n/2] 2n times
# C = [1,2,3...n/4] 3n times
# .
# .
# .
# X = A+B+C...
# X = [1,1,1,2,2,2,3,3..] etc Sorted one
# print X[n]  where n is the given index

def process(n,a,k):
    if len(a)>=k:
        return a[k-1]
    x = []
    i=1
    c = 1
    while(len(x)<=k):
        x.extend(a[:int(n/c)+2]*int(n*i))
        c = c*2
        i = i+1
    if len(x)<k:
        return -1
    x.sort()
    print(x)
    return x[k]

t = int(input())
for _ in range(t):
    n = int(input())
    a = list(map(int,input().split()))
    k = int(input())
    print(process(n,a,k))

# %%
# problem 2
# Minimum number of swaps to make two arrays identical (inter array swaps are allowed)

def minswaps(a,b,n): 
    temp1=''.join(sorted(a))
    temp2=''.join(sorted(a))
    if temp1 != temp2:
        return -1
    res = 0
    i = j = n-1
    while i >= 0: 
        while i>= 0 and a[i] != b[j]: 
            i -= 1
            res += 1
        if i >= 0: 
            i -= 1
            j -= 1
    return res
  
n = int(input())
a = "".join(input().split())
b = "".join(input().split())
print(minswaps(a, b, n))

# %% [markdown]
# ######  HackerEarth  Top frequent words

# %%
#k = ['welcome', 'well', 'geekss','the', 'world', 'of', 'geeks', 'this', 'portal', 'has', 'been', 'created', 'to', 'provide', 'to', 'written', 'well']
#{'welcome': 1, 'well': 2, 'geekss': 1, 'the': 1, 'world': 1, 'of': 1, 'geeks': 1, 'this': 1, 'portal': 1, 'has': 1, 'been': 1, 'created': 1, 'to': 2, 'provide': 1, 'written': 1}
# input
# 5
# abc
# abc
# cat 
# dog
# dog
# top 3
# Output: dog, abc, cat etc

def process(words, k):
    c={}
    for i in words:
        if i not in c:
            c[i] = 1
        else:
            c[i] += 1
    output = c.keys()
    output.sort(key = lambda w: (-c[w], w))
    print(" ".join(output[:k]))
t = input()
for _ in range(t):
    c = input()
    l=[]
    for i in range(c):
        string = raw_input()
        if string.startswith("top "):
            p = int(string.split(" ")[1])
            process(l,p)
        else:
            l.append(string)
            
# Using Counter Module
from collections import Counter 
k = ['welcome', 'well', 'geekss','the', 'world', 'of', 'geeks', 'this', 'portal', 'has', 'been', 'created', 'to', 'provide', 'to', 'written', 'well']
c = Counter(k) 
top = c.most_common(5)

# %% [markdown]
# ###### Balanced parantheses

# %%
# Balanced Parantheses 

# Method-I

def is_balanced(string):
    d = {'[':']','{':'}','(':')'}
    if string[0] not in d.keys():
        return False
    else:
        q = []
        for i in string:
            if i in d.keys():
                q.append(i)
            else:
                if i == d[q[-1]]:
                    q.pop()
                else:
                    return False
    return True

print(is_balanced("{{{}}}"))


# Method-II

def balanced(string):
    opened = "{[("
    parantheses = [('{','}'),('[',']'),('(',')')]
    last_opened = []
    for i in string:
        if i in opened:
            last_opened.append(i)
        else:
            if (last_opened,i) in parantheses:
                last_opened.pop()
            else:
                return False
    return True

for i in range(5):
    string = input("Enter String: ")
    print(balanced(string))
